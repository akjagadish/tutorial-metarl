# %%
import time
import torch
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from compositional_metarl.task import ContextualBandit
from compositional_metarl.model import QDNDLSTM as Agent
from compositional_metarl.model import LSTM as L2L
from compositional_metarl.utils import compute_stats, to_sqnp
from compositional_metarl.model.DND import compute_similarities
from compositional_metarl.model.utils import get_reward, compute_returns, compute_a2c_loss, get_reward_mab, run_agent_inference, one_hot_embedding
import matplotlib as mpl
import seaborn as sns
from matplotlib.ticker import MaxNLocator
import torch.nn.functional as F
from compositional_metarl.trainers import Trainer


sns.set(style='white', context='talk', palette='colorblind')
seed_val = 0 # 100 # 0 works for 64
torch.manual_seed(seed_val)
np.random.seed(seed_val)
torch.cuda.manual_seed(seed_val)

# %%
'''init task'''

n_arms = 10
PROBS = [0.9] # 0.2, 0.8, 0.9, 0.9, 0.6, 0.8
n_cues = 1    # len(PROBS)
task = ContextualBandit(probs=PROBS, ctx_dim=10, num_arms=n_arms)

# %%
'''init model and trainer'''

# DNDLSTM params
dim_hidden = 48
inp_dim =  None #n_arms + 1 + 1 # reward + trial index
inputs = 'context_action_reward'
dim_output = n_arms
estimate_Qvals = True
dict_len = 1000
kernel = 'cosine' # 'l1' or 'l2'
unique_keys = True
dnd_policy = '1NN' # 'softmax' or '1NN'

# training parameters
learning_rate = 1e-3 
n_epochs = 1000
n_rounds = 100
n_trials = 10
beta_e = 0.05 # weight for entropy loss
beta_v = 0.50
gamma = 0.8  # 0.8
normalize_return = True

# init agent and optimizer
agent = Agent(dim_hidden, dim_output, dict_len, input_dim=inp_dim, inputs=inputs, ctx_dim=task.ctx_dim, kernel=kernel, dnd_policy=dnd_policy, unique_keys=unique_keys, q_est=estimate_Qvals)
optimizer = torch.optim.Adam(agent.parameters(), lr=learning_rate)

# %%
'''train'''
log_return = np.zeros((n_epochs, n_cues, n_rounds))
log_loss_value = np.zeros((n_epochs, n_cues, n_rounds))
log_loss_policy = np.zeros((n_epochs, n_cues, n_rounds))
log_loss_entropy = np.zeros((n_epochs, n_cues, n_rounds))

log_Y = np.zeros((n_epochs, n_cues, n_rounds, n_arms))
log_Y_hat = np.zeros((n_epochs, n_cues, n_rounds, n_trials))
log_regret = np.zeros((n_epochs, n_cues, n_rounds, n_trials))

# loop over epoch
for i in range(n_epochs):
    time_start = time.time()
    # flush hippocampus which is context and representation
    agent.reset_memory()
    agent.turn_on_retrieval()

    # for c_indx, cue in enumerate(PROBS):
    # choose structure
    X, Y = task.sample(num_episodes=n_rounds, num_trials=n_trials, prob=PROBS[0], cxt_per_epoch=True)
    c_indx = 0

    # try different rounds of task
    for m in range(n_rounds): 
       
        # prealloc
        cumulative_reward = 0
        probs, rewards, values, entropys = [], [], [], []
        h_t, c_t = agent.get_init_states()
        a_t = torch.randint(high=n_arms, size=(1,))
        r_t = Y[m][0][a_t].type(torch.FloatTensor).data.reshape(-1)

        # loop over time, for one training example
        for t in range(n_trials):
        
            # only save memory at the end of the last trial
            agent.turn_off_encoding()
            if t == n_trials-1: # and cue == 'linear':
                agent.turn_on_encoding()

            # recurrent computation at time t
            x_t = X[m][t]
            if agent.inputs == 'context_action_reward':
                one_hot_a_t = one_hot_embedding(a_t, n_arms)
                x_t = torch.cat((x_t, one_hot_a_t.reshape(-1).type(torch.FloatTensor), 
                                 r_t.reshape(-1).type(torch.FloatTensor), torch.tensor(t).reshape(-1).type(torch.FloatTensor)), dim=0)
            output_t, cache_t = agent(x_t, h_t, c_t)
            a_t, prob_a_t, v_t, h_t, c_t = output_t
            f_t, i_t, o_t, rg_t, m_t, q_t, p_at = cache_t

            prob_t = torch.nn.functional.softmax(q_t.squeeze())
            entropy = -torch.sum(torch.log(prob_t)*prob_t)

            # compute immediate reward
            r_t = get_reward_mab(a_t, Y[m][t])

            # log
            probs.append(prob_a_t)
            rewards.append(r_t)
            entropys.append(entropy)
            values.append(v_t) 
            cumulative_reward += r_t
            log_Y_hat[i, c_indx, m, t] = a_t.item()
            log_regret[i, c_indx, m, t] = 1. - r_t

        returns = compute_returns(rewards, gamma=gamma, normalize=normalize_return)
        loss_policy, loss_value = compute_a2c_loss(probs, values, returns)
        loss_entropy = torch.stack(entropys).sum()
        loss = loss_policy + beta_v*loss_value - beta_e*loss_entropy
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        # log
        #log_Y[i, c_indx] = Y[m] #np.squeeze(Y[m].numpy())
        log_return[i, c_indx, m] = cumulative_reward / n_trials
        log_loss_value[i, c_indx, m] += loss_value.item() / n_trials
        log_loss_policy[i, c_indx, m] += loss_policy.item() / n_trials
        log_loss_entropy[i, c_indx, m] += loss_entropy.item() / n_trials

    # print out some stuff
    time_end = time.time()
    run_time = time_end - time_start
    print(
        'Epoch %3d | return = %.2f | loss: val = %.2f, pol = %.2f, entropy = %.2f | time = %.2f' %
        (i, log_return[i, c_indx, :].mean(), log_loss_value[i, c_indx, m], log_loss_policy[i, c_indx, m], log_loss_entropy[i, c_indx, m], run_time)
    )
# Out:
# <ipython-input-5-7b24cd91fa7c>:51: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   prob_t = torch.nn.functional.softmax(q_t.squeeze())
# Epoch   0 | return = 0.18 | loss: val = 0.46, pol = 0.01, entropy = 2.22 | time = 4.14
# Epoch   1 | return = 0.17 | loss: val = 0.46, pol = 0.22, entropy = 2.29 | time = 4.26
# Epoch   2 | return = 0.19 | loss: val = 0.06, pol = 0.04, entropy = 2.23 | time = 4.27
# Epoch   3 | return = 0.18 | loss: val = 0.66, pol = -0.25, entropy = 2.24 | time = 4.43
# Epoch   4 | return = 0.18 | loss: val = 0.11, pol = 0.16, entropy = 2.28 | time = 4.76
# Epoch   5 | return = 0.17 | loss: val = 0.26, pol = -0.13, entropy = 2.29 | time = 4.65
# Epoch   6 | return = 0.18 | loss: val = 0.41, pol = 0.71, entropy = 2.29 | time = 4.78
# Epoch   7 | return = 0.19 | loss: val = 0.21, pol = 0.34, entropy = 2.29 | time = 4.77
# Epoch   8 | return = 0.18 | loss: val = 0.61, pol = -0.43, entropy = 2.29 | time = 4.45
# Epoch   9 | return = 0.18 | loss: val = 0.43, pol = 0.91, entropy = 2.28 | time = 4.46
# Epoch  10 | return = 0.16 | loss: val = 0.22, pol = -0.02, entropy = 2.29 | time = 4.47
# Epoch  11 | return = 0.19 | loss: val = 0.46, pol = -0.68, entropy = 2.29 | time = 4.36
# Epoch  12 | return = 0.18 | loss: val = 0.28, pol = -0.17, entropy = 2.29 | time = 4.36
# Epoch  13 | return = 0.17 | loss: val = 0.31, pol = 0.09, entropy = 2.29 | time = 4.42
# Epoch  14 | return = 0.18 | loss: val = 0.08, pol = -0.60, entropy = 2.27 | time = 4.45
# Epoch  15 | return = 0.21 | loss: val = 0.16, pol = 0.56, entropy = 2.26 | time = 4.50
# Epoch  16 | return = 0.18 | loss: val = 0.39, pol = 0.08, entropy = 2.29 | time = 4.27
# Epoch  17 | return = 0.15 | loss: val = 0.41, pol = -0.55, entropy = 2.29 | time = 4.62
# Epoch  18 | return = 0.21 | loss: val = 0.18, pol = 0.65, entropy = 2.29 | time = 4.33
# Epoch  19 | return = 0.18 | loss: val = 0.10, pol = -1.03, entropy = 2.30 | time = 4.34
# Epoch  20 | return = 0.19 | loss: val = 0.05, pol = -0.64, entropy = 2.29 | time = 4.33
# Epoch  21 | return = 0.17 | loss: val = 0.38, pol = 0.36, entropy = 2.27 | time = 4.63
# Epoch  22 | return = 0.18 | loss: val = 0.23, pol = 1.06, entropy = 2.28 | time = 4.34
# Epoch  23 | return = 0.18 | loss: val = 0.59, pol = -0.46, entropy = 2.29 | time = 4.38
# Epoch  24 | return = 0.19 | loss: val = 0.31, pol = 0.29, entropy = 2.29 | time = 4.56
# Epoch  25 | return = 0.19 | loss: val = 0.17, pol = -0.09, entropy = 2.29 | time = 4.52
# Epoch  26 | return = 0.16 | loss: val = 0.59, pol = -0.65, entropy = 2.30 | time = 4.44
# Epoch  27 | return = 0.18 | loss: val = 0.29, pol = -0.10, entropy = 2.29 | time = 4.57
# Epoch  28 | return = 0.17 | loss: val = 0.16, pol = 0.42, entropy = 2.28 | time = 4.29
# Epoch  29 | return = 0.18 | loss: val = 0.25, pol = 0.14, entropy = 2.28 | time = 4.77
# Epoch  30 | return = 0.20 | loss: val = 0.19, pol = 0.26, entropy = 2.29 | time = 4.86
# Epoch  31 | return = 0.19 | loss: val = 0.19, pol = 0.91, entropy = 2.24 | time = 4.81
# Epoch  32 | return = 0.18 | loss: val = 0.23, pol = 0.25, entropy = 2.27 | time = 4.27
# Epoch  33 | return = 0.19 | loss: val = 0.17, pol = 0.66, entropy = 2.28 | time = 4.28
# Epoch  34 | return = 0.18 | loss: val = 0.15, pol = 0.40, entropy = 2.24 | time = 4.90
# Epoch  35 | return = 0.18 | loss: val = 0.29, pol = 0.12, entropy = 2.28 | time = 4.42
# Epoch  36 | return = 0.20 | loss: val = 0.33, pol = -0.49, entropy = 2.30 | time = 5.18
# Epoch  37 | return = 0.19 | loss: val = 0.41, pol = 0.35, entropy = 2.29 | time = 4.94
# Epoch  38 | return = 0.17 | loss: val = 0.23, pol = 0.19, entropy = 2.29 | time = 4.76
# Epoch  39 | return = 0.17 | loss: val = 0.25, pol = 0.34, entropy = 2.29 | time = 4.33
# Epoch  40 | return = 0.21 | loss: val = 0.20, pol = 0.34, entropy = 2.28 | time = 5.08
# Epoch  41 | return = 0.19 | loss: val = 0.19, pol = 0.78, entropy = 2.26 | time = 4.41
# Epoch  42 | return = 0.19 | loss: val = 0.18, pol = 0.34, entropy = 2.27 | time = 4.55
# Epoch  43 | return = 0.18 | loss: val = 0.20, pol = 1.01, entropy = 2.26 | time = 5.04
# Epoch  44 | return = 0.16 | loss: val = 0.47, pol = -0.75, entropy = 2.28 | time = 4.52
# Epoch  45 | return = 0.18 | loss: val = 0.28, pol = 1.11, entropy = 2.27 | time = 4.62
# Epoch  46 | return = 0.19 | loss: val = 0.17, pol = 0.93, entropy = 2.23 | time = 4.47
# Epoch  47 | return = 0.19 | loss: val = 0.16, pol = 0.04, entropy = 2.14 | time = 4.50
# Epoch  48 | return = 0.18 | loss: val = 0.23, pol = 1.30, entropy = 2.23 | time = 4.37
# Epoch  49 | return = 0.19 | loss: val = 0.19, pol = 0.57, entropy = 2.18 | time = 4.18
# Epoch  50 | return = 0.17 | loss: val = 0.31, pol = 1.26, entropy = 2.25 | time = 4.53
# Epoch  51 | return = 0.18 | loss: val = 0.24, pol = 0.56, entropy = 2.22 | time = 4.59
# Epoch  52 | return = 0.20 | loss: val = 0.06, pol = -0.72, entropy = 2.28 | time = 4.68
# Epoch  53 | return = 0.17 | loss: val = 0.31, pol = 0.53, entropy = 2.23 | time = 4.59
# Epoch  54 | return = 0.18 | loss: val = 0.16, pol = 0.09, entropy = 2.27 | time = 4.41
# Epoch  55 | return = 0.19 | loss: val = 0.21, pol = 0.76, entropy = 2.22 | time = 4.30
# Epoch  56 | return = 0.20 | loss: val = 0.20, pol = -0.22, entropy = 2.24 | time = 4.53
# Epoch  57 | return = 0.17 | loss: val = 0.24, pol = 0.99, entropy = 2.25 | time = 4.45
# Epoch  58 | return = 0.17 | loss: val = 0.25, pol = -0.26, entropy = 2.27 | time = 4.45
# Epoch  59 | return = 0.18 | loss: val = 0.35, pol = -0.36, entropy = 2.25 | time = 4.31
# Epoch  60 | return = 0.19 | loss: val = 0.19, pol = 0.88, entropy = 2.24 | time = 4.89
# Epoch  61 | return = 0.19 | loss: val = 0.05, pol = -0.60, entropy = 2.25 | time = 4.43
# Epoch  62 | return = 0.20 | loss: val = 0.25, pol = 0.51, entropy = 2.28 | time = 4.79
# Epoch  63 | return = 0.18 | loss: val = 0.34, pol = -0.50, entropy = 2.25 | time = 4.63
# Epoch  64 | return = 0.22 | loss: val = 0.42, pol = 0.51, entropy = 2.28 | time = 4.60
# Epoch  65 | return = 0.19 | loss: val = 0.08, pol = -0.92, entropy = 2.29 | time = 4.53
# Epoch  66 | return = 0.19 | loss: val = 0.31, pol = 0.13, entropy = 2.29 | time = 4.56
# Epoch  67 | return = 0.18 | loss: val = 0.07, pol = -0.83, entropy = 2.29 | time = 4.90
# Epoch  68 | return = 0.16 | loss: val = 0.19, pol = 0.65, entropy = 2.27 | time = 4.61
# Epoch  69 | return = 0.19 | loss: val = 0.25, pol = -0.01, entropy = 2.27 | time = 4.76
# Epoch  70 | return = 0.19 | loss: val = 0.47, pol = -0.87, entropy = 2.30 | time = 4.71
# Epoch  71 | return = 0.18 | loss: val = 0.27, pol = -0.61, entropy = 2.29 | time = 4.49
# Epoch  72 | return = 0.18 | loss: val = 0.12, pol = 0.09, entropy = 2.29 | time = 4.40
# Epoch  73 | return = 0.18 | loss: val = 0.14, pol = -1.17, entropy = 2.27 | time = 4.68
# Epoch  74 | return = 0.19 | loss: val = 0.19, pol = -0.21, entropy = 2.30 | time = 4.85
# Epoch  75 | return = 0.20 | loss: val = 0.23, pol = 0.78, entropy = 2.29 | time = 4.54
# Epoch  76 | return = 0.18 | loss: val = 0.16, pol = 0.10, entropy = 2.29 | time = 4.31
# Epoch  77 | return = 0.19 | loss: val = 0.11, pol = 0.31, entropy = 2.29 | time = 4.37
# Epoch  78 | return = 0.18 | loss: val = 0.38, pol = -0.39, entropy = 2.29 | time = 4.53
# Epoch  79 | return = 0.18 | loss: val = 0.20, pol = 0.73, entropy = 2.29 | time = 4.54
# Epoch  80 | return = 0.20 | loss: val = 0.37, pol = -0.36, entropy = 2.27 | time = 4.44
# Epoch  81 | return = 0.18 | loss: val = 0.26, pol = 0.14, entropy = 2.29 | time = 4.58
# Epoch  82 | return = 0.18 | loss: val = 0.24, pol = 0.15, entropy = 2.30 | time = 4.54
# Epoch  83 | return = 0.19 | loss: val = 0.36, pol = 0.49, entropy = 2.29 | time = 4.90
# Epoch  84 | return = 0.17 | loss: val = 0.17, pol = -0.01, entropy = 2.29 | time = 4.73
# Epoch  85 | return = 0.18 | loss: val = 0.27, pol = 0.18, entropy = 2.29 | time = 4.89
# Epoch  86 | return = 0.18 | loss: val = 0.30, pol = -0.06, entropy = 2.29 | time = 4.70
# Epoch  87 | return = 0.18 | loss: val = 0.23, pol = -0.44, entropy = 2.29 | time = 4.54
# Epoch  88 | return = 0.19 | loss: val = 0.13, pol = 0.48, entropy = 2.29 | time = 4.52
# Epoch  89 | return = 0.19 | loss: val = 0.17, pol = 0.60, entropy = 2.29 | time = 4.42
# Epoch  90 | return = 0.18 | loss: val = 0.13, pol = 0.23, entropy = 2.29 | time = 4.48
# Epoch  91 | return = 0.20 | loss: val = 0.24, pol = 0.16, entropy = 2.30 | time = 4.58
# Epoch  92 | return = 0.17 | loss: val = 0.17, pol = -0.22, entropy = 2.29 | time = 4.75
# Epoch  93 | return = 0.18 | loss: val = 0.15, pol = 0.09, entropy = 2.29 | time = 4.40
# Epoch  94 | return = 0.19 | loss: val = 0.03, pol = -0.41, entropy = 2.30 | time = 4.43
# Epoch  95 | return = 0.18 | loss: val = 0.28, pol = 1.47, entropy = 2.27 | time = 4.63
# Epoch  96 | return = 0.20 | loss: val = 0.05, pol = -0.71, entropy = 2.30 | time = 4.37
# Epoch  97 | return = 0.19 | loss: val = 0.41, pol = -0.11, entropy = 2.29 | time = 4.64
# Epoch  98 | return = 0.20 | loss: val = 0.21, pol = 0.61, entropy = 2.30 | time = 4.48
# Epoch  99 | return = 0.19 | loss: val = 0.19, pol = 0.88, entropy = 2.30 | time = 4.29
# Epoch 100 | return = 0.18 | loss: val = 0.05, pol = -0.67, entropy = 2.30 | time = 4.64
# Epoch 101 | return = 0.18 | loss: val = 0.15, pol = 0.24, entropy = 2.30 | time = 4.30
# Epoch 102 | return = 0.19 | loss: val = 0.23, pol = 0.47, entropy = 2.29 | time = 4.59
# Epoch 103 | return = 0.20 | loss: val = 0.27, pol = 0.13, entropy = 2.29 | time = 4.69
# Epoch 104 | return = 0.20 | loss: val = 0.21, pol = 0.59, entropy = 2.30 | time = 4.59
# Epoch 105 | return = 0.18 | loss: val = 0.18, pol = -0.14, entropy = 2.30 | time = 4.51
# Epoch 106 | return = 0.17 | loss: val = 0.19, pol = 0.64, entropy = 2.29 | time = 4.19
# Epoch 107 | return = 0.17 | loss: val = 0.16, pol = 0.23, entropy = 2.29 | time = 4.47
# Epoch 108 | return = 0.22 | loss: val = 0.46, pol = -0.49, entropy = 2.29 | time = 4.71
# Epoch 109 | return = 0.18 | loss: val = 0.36, pol = -0.33, entropy = 2.29 | time = 4.67
# Epoch 110 | return = 0.18 | loss: val = 0.24, pol = 0.02, entropy = 2.29 | time = 4.58
# Epoch 111 | return = 0.19 | loss: val = 0.19, pol = 0.57, entropy = 2.28 | time = 4.64
# Epoch 112 | return = 0.17 | loss: val = 0.21, pol = 0.95, entropy = 2.28 | time = 4.71
# Epoch 113 | return = 0.17 | loss: val = 0.06, pol = -0.77, entropy = 2.29 | time = 4.46
# Epoch 114 | return = 0.18 | loss: val = 0.26, pol = 0.28, entropy = 2.29 | time = 4.68
# Epoch 115 | return = 0.19 | loss: val = 0.15, pol = 0.35, entropy = 2.29 | time = 4.59
# Epoch 116 | return = 0.16 | loss: val = 0.21, pol = 0.68, entropy = 2.29 | time = 4.50
# Epoch 117 | return = 0.19 | loss: val = 0.17, pol = 0.11, entropy = 2.29 | time = 4.37
# Epoch 118 | return = 0.19 | loss: val = 0.09, pol = -0.89, entropy = 2.29 | time = 4.63
# Epoch 119 | return = 0.18 | loss: val = 0.24, pol = 0.73, entropy = 2.28 | time = 4.72
# Epoch 120 | return = 0.19 | loss: val = 0.29, pol = -0.19, entropy = 2.29 | time = 4.47
# Epoch 121 | return = 0.18 | loss: val = 0.25, pol = 0.23, entropy = 2.29 | time = 4.39
# Epoch 122 | return = 0.19 | loss: val = 0.26, pol = -0.15, entropy = 2.29 | time = 4.57
# Epoch 123 | return = 0.18 | loss: val = 0.44, pol = -0.55, entropy = 2.29 | time = 4.91
# Epoch 124 | return = 0.18 | loss: val = 0.47, pol = -0.49, entropy = 2.30 | time = 5.00
# Epoch 125 | return = 0.18 | loss: val = 0.24, pol = 0.74, entropy = 2.26 | time = 5.27
# Epoch 126 | return = 0.17 | loss: val = 0.31, pol = -0.15, entropy = 2.30 | time = 4.73
# Epoch 127 | return = 0.18 | loss: val = 0.15, pol = 0.13, entropy = 2.28 | time = 4.74

# %% [markdown]
# ## save model

# %%
model_name = f"agent_contextualbandits_jwang"
torch.save(agent.state_dict(), model_name +".pt")

# %%
file_name = model_name
np.savez(file_name, n_rounds=n_rounds, n_epochs=n_epochs, n_trials=n_trials, log_Y=log_Y, log_Y_hat=log_Y_hat, log_return=log_return, log_regret=log_regret, log_loss_value=log_loss_value, log_loss_policy=log_loss_policy)

# %% [markdown]
# ## figures

# %%
'''loss functions'''

f, axes = plt.subplots(1, 2, figsize=(8, 3), dpi=125)
axes[0].plot(log_loss_policy.mean(2))
axes[0].xaxis.set_major_locator(MaxNLocator(integer=True))
axes[0].set_ylabel('Policy loss')
axes[0].set_xlabel('Epoch')

axes[1].plot(log_loss_value.mean(2))
axes[1].xaxis.set_major_locator(MaxNLocator(integer=True))
axes[1].set_ylabel('Value loss')
axes[1].set_xlabel('Epoch')

plt.legend(PROBS)
sns.despine()
f.tight_layout()

# %%
'''learning curves'''

f, axes = plt.subplots(1, 2, figsize=(8, 3), dpi=125)
axes[0].plot(log_return.mean(2)[:n_epochs])
axes[0].set_ylabel('Return')
axes[0].set_xlabel('Epoch')
axes[0].xaxis.set_major_locator(MaxNLocator(integer=True))

axes[1].plot(log_regret.cumsum(3).max(3).mean(2))
axes[1].xaxis.set_major_locator(MaxNLocator(integer=True))
axes[1].set_ylabel('Cum. Regret')
axes[1].set_xlabel('Epoch')

axes[0].legend(PROBS)
sns.despine()
f.tight_layout()

# %%
aa = np.ones(n_arms)
b = 0

# %%
''' model evaluation for different cues'''

cue = PROBS[0]
n_runs = 10
cxt = 0
X, Y = task._sample_one_episode(aa, b, cue, n_runs)
# task.context[cxt], task.arm_per_context[cxt]

# %%
# params
n_cues = len(PROBS)
 
# set up the color scheme
c = np.arange(n_runs+1)
norm = mpl.colors.Normalize(vmin=c.min(), vmax=c.max())
cmap = mpl.cm.ScalarMappable(norm=norm, cmap=mpl.cm.cividis_r)
cmap.set_array([])

# run model for n_runs
agent.eval()
agent.turn_on_encoding()
agent.turn_on_retrieval()
#agent.turn_off_encoding()
#agent.turn_off_retrieval()

# set init states
h_t, c_t = agent.get_init_states()
h_t, c_t = torch.zeros_like(h_t), torch.zeros_like(c_t) 
a_t = torch.randint(high=dim_output,size=(1,))
r_t = Y[0][a_t] 
actions, dist, values, temps, regrets = [], [], [], [], []
f, ax = plt.subplots(1, 1, figsize=(10, 5), dpi=100)

# run model
for t in range(n_runs):
    h_t1 = h_t
    c_t1 = c_t 
    x_t = X[t]
    
    if agent.inputs == 'context_action_reward':
        one_hot_a_t = one_hot_embedding(a_t, n_arms)
        x_t = torch.cat((x_t, one_hot_a_t.reshape(-1).type(torch.FloatTensor), 
                         r_t.reshape(-1).type(torch.FloatTensor), torch.tensor(t).reshape(-1).type(torch.FloatTensor)), dim=0)
    output_t, c = agent(x_t, h_t, c_t) 
    a_t, prob_a_t, v_t, h_t, c_t = output_t
    f_t, i_t, o_t, rg_t, m_t, q_t, p_at = c
    a_t = torch.argmax(q_t)
    r_t = Y[t][a_t] 
    
    regrets.append(1. - r_t)
    ax.plot(q_t.detach().numpy().T, c=cmap.to_rgba(t + 1))
    dist.append(torch.sum(F.pairwise_distance(h_t1, h_t, p=2)))
    actions.append(a_t) 
    values.append(q_t[0][b]) 
    
# format figure
ax.xaxis.set_major_locator(MaxNLocator(integer=True))
ax.set(xlabel='Arms',
       ylabel='Q-value',
      title= 'Q-values for Contextual Bandit w/ Arm {} to be the best arm'.format(b))
cbar = plt.colorbar(cmap, ticks=np.arange(n_runs+1, step=n_runs/5), ax=ax)
cbar.set_label('Runs', rotation=90)
sns.despine()
plt.show()

# %%
f, ax = plt.subplots(1, 1, figsize=(10, 5), dpi=100)
_ = ax.hist(actions)
ax.set(xlabel='Arm',
       ylabel='Number of runs per arm', title = cue)
sns.despine()
plt.show()

# %%
f, ax = plt.subplots(1, 1, figsize=(10, 5), dpi=100)
ax.plot(regrets)
ax.set(xlabel='Runs',
       ylabel='Regret', title = cue)
sns.despine()
plt.show()
