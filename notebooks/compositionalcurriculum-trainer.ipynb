# %%
import time
import torch
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from compositional_metarl.task import MultiArmedBandit, BlockMABs
from compositional_metarl.model import QDNDLSTM as Agent
from compositional_metarl.utils import compute_stats, to_sqnp
from compositional_metarl.model.DND import compute_similarities
from compositional_metarl.model.utils import get_reward, compute_returns, compute_a2c_loss, get_reward_mab, run_agent_inference, one_hot_embedding
import matplotlib as mpl
import seaborn as sns
from matplotlib.ticker import MaxNLocator
import torch.nn.functional as F
from compositional_metarl.trainers import BlockTrainer as Trainer
from compositional_metarl.trainers import evaluate

sns.set(style='white', context='talk', palette='colorblind')
seed_val = 0 
torch.manual_seed(seed_val)
np.random.seed(seed_val)
torch.cuda.manual_seed(seed_val)

# %%
'''init task'''

start_arm = 0
end_arm = 7
n_arms = (end_arm - start_arm) + 1
n_rounds_per_kernel = 1 # per function
n_blocks = 50
n_trials = 10
composition_block = True
normalize_rewards = True
noise_per_arm = None #'per_arm'
cue_per_epoch = True
CUES =  {'linear': [1., 0.],  'periodic': [0., 1.], 'linperiodic': [1., 1.]}
ctx_dim = len(CUES['linear'])
n_cues = len(CUES)
aoi = {'linear': 7, 'periodic': 1,
       'linperiodic': 6}

# %%
bandit = MultiArmedBandit(cues=CUES, start_arm=start_arm, end_arm=end_arm, ctx_dim=ctx_dim, num_rounds=n_rounds_per_kernel, 
                        normalize=normalize_rewards, noise_per_arm=noise_per_arm, cue_per_epoch=cue_per_epoch,
                        best_arms=aoi)
task = BlockMABs(bandit, num_blocks=n_blocks, composition_block=composition_block, num_rounds=n_rounds_per_kernel)

# %%
'''init model'''

# DNDLSTM params
dim_hidden = 48 #64
inp_dim = None
inputs = 'context_block_action_reward'
dim_output = n_arms
estimate_Qvals = True
dict_len = 1000
kernel = 'cosine' # 'l1' or 'l2'
dnd_policy = 'softmax' # 'softmax' or '1NN'
unique_keys = True
exclude_key = True

# %%
agent = Agent(dim_hidden, dim_output, dict_len, input_dim=inp_dim, ctx_dim=ctx_dim, inputs=inputs, kernel=kernel, dnd_policy=dnd_policy, unique_keys=unique_keys, q_est=estimate_Qvals)

# %%
'''init trainer'''

n_epochs = 1000
learning_rate = 1e-3 #5e-4 
gamma = 0.8 # 0.8
simulate_annealing = False
beta = .05 # weight for entropy loss
normalize_return = True
early_stopping = False
infer_composition = False

# %%
trainer = Trainer(agent, task, early_stopping=early_stopping, seed=seed_val, lr=learning_rate, n_trials=n_trials, beta=beta, 
                  gamma=gamma, normalize_return=normalize_return, simulate_annealing=simulate_annealing, infer_composition=infer_composition, n_epochs=n_epochs)

# %%
'''train model'''

out, avg_train_loss, avg_cum_rewards, _ = trainer.train()
n_epochs = trainer.current_epoch + 1
# Out:
# Epoch 1 / 1000| cum. return = 0.49 | loss: val = 1.23, pol = -0.04, entropy = 6.17 | time = 7.98
# Epoch 2 / 1000| cum. return = 0.51 | loss: val = 1.12, pol = -0.14, entropy = 6.15 | time = 8.08
# Epoch 3 / 1000| cum. return = 0.50 | loss: val = 1.06, pol = -0.16, entropy = 6.11 | time = 7.80
# Epoch 4 / 1000| cum. return = 0.51 | loss: val = 1.02, pol = 0.18, entropy = 5.99 | time = 8.10
# Epoch 5 / 1000| cum. return = 0.49 | loss: val = 0.90, pol = -0.10, entropy = 6.02 | time = 7.96
# Epoch 6 / 1000| cum. return = 0.50 | loss: val = 0.83, pol = -0.01, entropy = 5.96 | time = 8.29
# Epoch 7 / 1000| cum. return = 0.50 | loss: val = 0.79, pol = 0.15, entropy = 5.90 | time = 7.88
# Epoch 8 / 1000| cum. return = 0.51 | loss: val = 0.80, pol = -0.02, entropy = 6.09 | time = 8.60
# Epoch 9 / 1000| cum. return = 0.48 | loss: val = 0.82, pol = -0.03, entropy = 6.20 | time = 8.59
# Epoch 10 / 1000| cum. return = 0.51 | loss: val = 0.76, pol = 0.18, entropy = 6.19 | time = 8.85
# Epoch 11 / 1000| cum. return = 0.49 | loss: val = 0.71, pol = 0.11, entropy = 6.17 | time = 8.97
# Epoch 12 / 1000| cum. return = 0.49 | loss: val = 0.70, pol = -0.15, entropy = 6.18 | time = 8.91
# Epoch 13 / 1000| cum. return = 0.49 | loss: val = 0.77, pol = -0.10, entropy = 6.20 | time = 9.15
# Epoch 14 / 1000| cum. return = 0.48 | loss: val = 0.78, pol = 0.28, entropy = 6.20 | time = 9.40
# Epoch 15 / 1000| cum. return = 0.50 | loss: val = 0.74, pol = -0.01, entropy = 6.21 | time = 8.97
# Epoch 16 / 1000| cum. return = 0.51 | loss: val = 0.77, pol = -0.08, entropy = 6.18 | time = 8.55
# Epoch 17 / 1000| cum. return = 0.51 | loss: val = 0.70, pol = 0.01, entropy = 6.19 | time = 8.64
# Epoch 18 / 1000| cum. return = 0.49 | loss: val = 0.78, pol = -0.12, entropy = 6.21 | time = 8.64
# Epoch 19 / 1000| cum. return = 0.50 | loss: val = 0.65, pol = 0.17, entropy = 6.21 | time = 8.75
# Epoch 20 / 1000| cum. return = 0.51 | loss: val = 0.71, pol = -0.27, entropy = 6.20 | time = 8.10
# Epoch 21 / 1000| cum. return = 0.51 | loss: val = 0.75, pol = 0.23, entropy = 6.20 | time = 8.66
# Epoch 22 / 1000| cum. return = 0.50 | loss: val = 0.68, pol = 0.05, entropy = 6.21 | time = 8.52
# Epoch 23 / 1000| cum. return = 0.51 | loss: val = 0.70, pol = -0.18, entropy = 6.21 | time = 8.38
# Epoch 24 / 1000| cum. return = 0.51 | loss: val = 0.70, pol = 0.13, entropy = 6.21 | time = 8.62
# Epoch 25 / 1000| cum. return = 0.52 | loss: val = 0.63, pol = -0.01, entropy = 6.18 | time = 8.26
# Epoch 26 / 1000| cum. return = 0.50 | loss: val = 0.69, pol = -0.06, entropy = 6.17 | time = 8.40
# Epoch 27 / 1000| cum. return = 0.48 | loss: val = 0.75, pol = -0.04, entropy = 6.20 | time = 7.97
# Epoch 28 / 1000| cum. return = 0.50 | loss: val = 0.70, pol = -0.06, entropy = 6.19 | time = 8.20
# Epoch 29 / 1000| cum. return = 0.47 | loss: val = 0.78, pol = -0.23, entropy = 6.20 | time = 8.13
# Epoch 30 / 1000| cum. return = 0.50 | loss: val = 0.73, pol = 0.14, entropy = 6.21 | time = 8.41
# Epoch 31 / 1000| cum. return = 0.49 | loss: val = 0.67, pol = -0.19, entropy = 6.19 | time = 8.17
# Epoch 32 / 1000| cum. return = 0.49 | loss: val = 0.70, pol = -0.05, entropy = 6.17 | time = 8.31
# Epoch 33 / 1000| cum. return = 0.51 | loss: val = 0.65, pol = 0.21, entropy = 6.20 | time = 8.07
# Epoch 34 / 1000| cum. return = 0.50 | loss: val = 0.65, pol = -0.26, entropy = 6.21 | time = 8.39
# Epoch 35 / 1000| cum. return = 0.50 | loss: val = 0.72, pol = 0.19, entropy = 6.21 | time = 8.21
# Epoch 36 / 1000| cum. return = 0.51 | loss: val = 0.67, pol = -0.14, entropy = 6.21 | time = 8.09
# Epoch 37 / 1000| cum. return = 0.52 | loss: val = 0.66, pol = 0.01, entropy = 6.20 | time = 8.11
# Epoch 38 / 1000| cum. return = 0.51 | loss: val = 0.77, pol = -0.18, entropy = 6.20 | time = 8.09
# Epoch 39 / 1000| cum. return = 0.50 | loss: val = 0.70, pol = 0.08, entropy = 6.19 | time = 8.19
# Epoch 40 / 1000| cum. return = 0.51 | loss: val = 0.72, pol = -0.31, entropy = 6.12 | time = 8.09
# Epoch 41 / 1000| cum. return = 0.49 | loss: val = 0.66, pol = 0.11, entropy = 6.10 | time = 8.20
# Epoch 42 / 1000| cum. return = 0.51 | loss: val = 0.69, pol = -0.03, entropy = 6.14 | time = 8.31
# Epoch 43 / 1000| cum. return = 0.51 | loss: val = 0.63, pol = -0.07, entropy = 6.16 | time = 8.03
# Epoch 44 / 1000| cum. return = 0.51 | loss: val = 0.68, pol = 0.03, entropy = 6.16 | time = 7.75
# Epoch 45 / 1000| cum. return = 0.52 | loss: val = 0.65, pol = -0.14, entropy = 6.16 | time = 8.16
# Epoch 46 / 1000| cum. return = 0.48 | loss: val = 0.77, pol = 0.03, entropy = 6.18 | time = 8.02
# Epoch 47 / 1000| cum. return = 0.49 | loss: val = 0.73, pol = -0.35, entropy = 6.15 | time = 7.70
# Epoch 48 / 1000| cum. return = 0.50 | loss: val = 0.64, pol = 0.01, entropy = 6.13 | time = 8.17
# Epoch 49 / 1000| cum. return = 0.50 | loss: val = 0.70, pol = -0.27, entropy = 6.16 | time = 8.24
# Epoch 50 / 1000| cum. return = 0.49 | loss: val = 0.72, pol = 0.19, entropy = 6.17 | time = 8.17
# Epoch 51 / 1000| cum. return = 0.50 | loss: val = 0.76, pol = -0.28, entropy = 6.17 | time = 7.94
# Epoch 52 / 1000| cum. return = 0.49 | loss: val = 0.71, pol = 0.14, entropy = 6.18 | time = 8.08
# Epoch 53 / 1000| cum. return = 0.50 | loss: val = 0.69, pol = -0.28, entropy = 6.18 | time = 8.01
# Epoch 54 / 1000| cum. return = 0.49 | loss: val = 0.73, pol = -0.00, entropy = 6.19 | time = 8.39
# Epoch 55 / 1000| cum. return = 0.51 | loss: val = 0.65, pol = 0.06, entropy = 6.19 | time = 8.47
# Epoch 56 / 1000| cum. return = 0.49 | loss: val = 0.70, pol = 0.01, entropy = 6.19 | time = 8.27
# Epoch 57 / 1000| cum. return = 0.50 | loss: val = 0.71, pol = -0.18, entropy = 6.18 | time = 8.01
# Epoch 58 / 1000| cum. return = 0.49 | loss: val = 0.65, pol = -0.01, entropy = 6.18 | time = 8.36
# Epoch 59 / 1000| cum. return = 0.49 | loss: val = 0.70, pol = -0.22, entropy = 6.18 | time = 8.69
# Epoch 60 / 1000| cum. return = 0.49 | loss: val = 0.70, pol = -0.04, entropy = 6.18 | time = 8.08
# Epoch 61 / 1000| cum. return = 0.51 | loss: val = 0.62, pol = 0.09, entropy = 6.18 | time = 7.81
# Epoch 62 / 1000| cum. return = 0.50 | loss: val = 0.72, pol = -0.33, entropy = 6.19 | time = 8.54
# Epoch 63 / 1000| cum. return = 0.47 | loss: val = 0.75, pol = 0.03, entropy = 6.20 | time = 7.86
# Epoch 64 / 1000| cum. return = 0.52 | loss: val = 0.58, pol = 0.06, entropy = 6.19 | time = 8.53
# Epoch 65 / 1000| cum. return = 0.50 | loss: val = 0.70, pol = -0.28, entropy = 6.18 | time = 8.52
# Epoch 66 / 1000| cum. return = 0.52 | loss: val = 0.63, pol = 0.11, entropy = 6.18 | time = 8.79
# Epoch 67 / 1000| cum. return = 0.49 | loss: val = 0.74, pol = -0.17, entropy = 6.18 | time = 8.76
# Epoch 68 / 1000| cum. return = 0.47 | loss: val = 0.65, pol = -0.03, entropy = 6.19 | time = 8.83
# Epoch 69 / 1000| cum. return = 0.51 | loss: val = 0.59, pol = -0.14, entropy = 6.19 | time = 8.31
# Epoch 70 / 1000| cum. return = 0.52 | loss: val = 0.74, pol = -0.36, entropy = 6.15 | time = 8.14
# Epoch 71 / 1000| cum. return = 0.49 | loss: val = 0.72, pol = -0.06, entropy = 6.11 | time = 8.68
# Epoch 72 / 1000| cum. return = 0.51 | loss: val = 0.64, pol = -0.06, entropy = 6.17 | time = 8.26
# Epoch 73 / 1000| cum. return = 0.48 | loss: val = 0.73, pol = 0.24, entropy = 6.17 | time = 8.49
# Epoch 74 / 1000| cum. return = 0.50 | loss: val = 0.64, pol = -0.23, entropy = 6.16 | time = 8.43
# Epoch 75 / 1000| cum. return = 0.50 | loss: val = 0.67, pol = -0.02, entropy = 6.13 | time = 9.00
# Epoch 76 / 1000| cum. return = 0.48 | loss: val = 0.73, pol = 0.04, entropy = 6.17 | time = 8.84
# Epoch 77 / 1000| cum. return = 0.51 | loss: val = 0.63, pol = -0.11, entropy = 6.17 | time = 8.80
# Epoch 78 / 1000| cum. return = 0.49 | loss: val = 0.67, pol = -0.04, entropy = 6.16 | time = 8.68
# Epoch 79 / 1000| cum. return = 0.52 | loss: val = 0.68, pol = -0.06, entropy = 6.11 | time = 9.71
# Epoch 80 / 1000| cum. return = 0.52 | loss: val = 0.80, pol = -0.45, entropy = 5.83 | time = 8.89
# Epoch 81 / 1000| cum. return = 0.55 | loss: val = 0.73, pol = -0.17, entropy = 5.86 | time = 8.60
# Epoch 82 / 1000| cum. return = 0.50 | loss: val = 0.71, pol = -0.09, entropy = 5.94 | time = 9.06
# Epoch 83 / 1000| cum. return = 0.50 | loss: val = 0.71, pol = 0.04, entropy = 6.08 | time = 9.08
# Epoch 84 / 1000| cum. return = 0.49 | loss: val = 0.60, pol = -0.01, entropy = 6.14 | time = 8.88
# Epoch 85 / 1000| cum. return = 0.51 | loss: val = 0.59, pol = 0.06, entropy = 6.17 | time = 8.76
# Epoch 86 / 1000| cum. return = 0.53 | loss: val = 0.59, pol = -0.03, entropy = 6.07 | time = 8.40
# Epoch 87 / 1000| cum. return = 0.56 | loss: val = 0.61, pol = -0.29, entropy = 5.82 | time = 8.81
# Epoch 88 / 1000| cum. return = 0.58 | loss: val = 0.59, pol = -0.10, entropy = 5.71 | time = 8.68
# Epoch 89 / 1000| cum. return = 0.60 | loss: val = 0.68, pol = -0.43, entropy = 5.28 | time = 8.70
# Epoch 90 / 1000| cum. return = 0.60 | loss: val = 0.67, pol = -0.56, entropy = 5.23 | time = 8.38
# Epoch 91 / 1000| cum. return = 0.63 | loss: val = 0.61, pol = -0.31, entropy = 4.97 | time = 8.58
# Epoch 92 / 1000| cum. return = 0.63 | loss: val = 0.66, pol = -0.30, entropy = 5.13 | time = 8.24
# Epoch 93 / 1000| cum. return = 0.70 | loss: val = 0.54, pol = -0.43, entropy = 4.82 | time = 8.28
# Epoch 94 / 1000| cum. return = 0.73 | loss: val = 0.43, pol = -0.20, entropy = 4.55 | time = 8.01
# Epoch 95 / 1000| cum. return = 0.71 | loss: val = 0.50, pol = -0.38, entropy = 4.49 | time = 8.36
# Epoch 96 / 1000| cum. return = 0.75 | loss: val = 0.39, pol = -0.20, entropy = 4.15 | time = 8.41
# Epoch 97 / 1000| cum. return = 0.75 | loss: val = 0.36, pol = -0.11, entropy = 3.81 | time = 8.14
# Epoch 98 / 1000| cum. return = 0.78 | loss: val = 0.32, pol = -0.42, entropy = 3.69 | time = 8.43
# Epoch 99 / 1000| cum. return = 0.78 | loss: val = 0.32, pol = -0.19, entropy = 3.52 | time = 8.22
# Epoch 100 / 1000| cum. return = 0.79 | loss: val = 0.26, pol = -0.30, entropy = 3.61 | time = 7.89
# Epoch 101 / 1000| cum. return = 0.80 | loss: val = 0.29, pol = -0.32, entropy = 3.46 | time = 8.68
# Epoch 102 / 1000| cum. return = 0.83 | loss: val = 0.21, pol = -0.22, entropy = 2.78 | time = 8.53
# Epoch 103 / 1000| cum. return = 0.84 | loss: val = 0.18, pol = -0.22, entropy = 2.84 | time = 8.59
# Epoch 104 / 1000| cum. return = 0.83 | loss: val = 0.18, pol = -0.19, entropy = 3.09 | time = 8.57
# Epoch 105 / 1000| cum. return = 0.85 | loss: val = 0.14, pol = -0.21, entropy = 3.09 | time = 8.07
# Epoch 106 / 1000| cum. return = 0.85 | loss: val = 0.11, pol = -0.17, entropy = 3.06 | time = 8.24
# Epoch 107 / 1000| cum. return = 0.84 | loss: val = 0.14, pol = -0.27, entropy = 3.04 | time = 7.97
# Epoch 108 / 1000| cum. return = 0.85 | loss: val = 0.16, pol = -0.26, entropy = 2.72 | time = 7.69
# Epoch 109 / 1000| cum. return = 0.87 | loss: val = 0.09, pol = -0.12, entropy = 2.75 | time = 8.45
# Epoch 110 / 1000| cum. return = 0.86 | loss: val = 0.11, pol = -0.13, entropy = 3.02 | time = 8.56
# Epoch 111 / 1000| cum. return = 0.85 | loss: val = 0.16, pol = -0.26, entropy = 2.83 | time = 8.74
# Epoch 112 / 1000| cum. return = 0.86 | loss: val = 0.16, pol = -0.19, entropy = 2.97 | time = 8.70
# Epoch 113 / 1000| cum. return = 0.87 | loss: val = 0.13, pol = -0.18, entropy = 2.90 | time = 8.43
# Epoch 114 / 1000| cum. return = 0.87 | loss: val = 0.08, pol = -0.11, entropy = 2.70 | time = 8.77
# Epoch 115 / 1000| cum. return = 0.86 | loss: val = 0.09, pol = -0.10, entropy = 2.91 | time = 8.60
# Epoch 116 / 1000| cum. return = 0.87 | loss: val = 0.08, pol = -0.17, entropy = 2.89 | time = 8.32
# Epoch 117 / 1000| cum. return = 0.89 | loss: val = 0.07, pol = -0.10, entropy = 2.68 | time = 8.16
# Epoch 118 / 1000| cum. return = 0.88 | loss: val = 0.08, pol = -0.13, entropy = 2.66 | time = 8.04
# Epoch 119 / 1000| cum. return = 0.88 | loss: val = 0.07, pol = -0.10, entropy = 2.86 | time = 8.30
# Epoch 120 / 1000| cum. return = 0.88 | loss: val = 0.11, pol = -0.18, entropy = 2.82 | time = 8.57
# Epoch 121 / 1000| cum. return = 0.90 | loss: val = 0.07, pol = -0.15, entropy = 2.74 | time = 8.14
# Epoch 122 / 1000| cum. return = 0.89 | loss: val = 0.11, pol = -0.17, entropy = 2.76 | time = 8.87
# Epoch 123 / 1000| cum. return = 0.89 | loss: val = 0.09, pol = -0.13, entropy = 2.71 | time = 8.89
# Epoch 124 / 1000| cum. return = 0.90 | loss: val = 0.10, pol = -0.15, entropy = 2.74 | time = 8.48
# Epoch 125 / 1000| cum. return = 0.88 | loss: val = 0.12, pol = -0.16, entropy = 2.92 | time = 8.82
# Epoch 126 / 1000| cum. return = 0.91 | loss: val = 0.10, pol = -0.18, entropy = 2.67 | time = 8.18
# Epoch 127 / 1000| cum. return = 0.91 | loss: val = 0.08, pol = -0.13, entropy = 2.44 | time = 8.72
# Epoch 128 / 1000| cum. return = 0.90 | loss: val = 0.09, pol = -0.12, entropy = 2.44 | time = 8.72
# Epoch 129 / 1000| cum. return = 0.91 | loss: val = 0.10, pol = -0.14, entropy = 2.49 | time = 8.69
# Epoch 130 / 1000| cum. return = 0.89 | loss: val = 0.11, pol = -0.16, entropy = 2.62 | time = 8.59
# Epoch 131 / 1000| cum. return = 0.91 | loss: val = 0.09, pol = -0.10, entropy = 2.28 | time = 8.41
# Epoch 132 / 1000| cum. return = 0.91 | loss: val = 0.07, pol = -0.12, entropy = 2.39 | time = 8.63
# Epoch 133 / 1000| cum. return = 0.90 | loss: val = 0.10, pol = -0.17, entropy = 2.60 | time = 9.27
# Epoch 134 / 1000| cum. return = 0.90 | loss: val = 0.09, pol = -0.08, entropy = 2.28 | time = 9.25
# Epoch 135 / 1000| cum. return = 0.91 | loss: val = 0.07, pol = -0.10, entropy = 2.40 | time = 9.73
# Epoch 136 / 1000| cum. return = 0.90 | loss: val = 0.08, pol = -0.14, entropy = 2.65 | time = 9.13
# Epoch 137 / 1000| cum. return = 0.90 | loss: val = 0.08, pol = -0.13, entropy = 2.67 | time = 8.51
# Epoch 138 / 1000| cum. return = 0.91 | loss: val = 0.08, pol = -0.12, entropy = 2.61 | time = 9.12
# Epoch 139 / 1000| cum. return = 0.90 | loss: val = 0.08, pol = -0.17, entropy = 2.55 | time = 9.11
# Epoch 140 / 1000| cum. return = 0.91 | loss: val = 0.08, pol = -0.11, entropy = 2.46 | time = 9.26
# Epoch 141 / 1000| cum. return = 0.92 | loss: val = 0.08, pol = -0.12, entropy = 2.35 | time = 9.28
# Epoch 142 / 1000| cum. return = 0.91 | loss: val = 0.07, pol = -0.12, entropy = 2.57 | time = 8.89
# Epoch 143 / 1000| cum. return = 0.91 | loss: val = 0.08, pol = -0.14, entropy = 2.54 | time = 9.04
# Epoch 144 / 1000| cum. return = 0.90 | loss: val = 0.09, pol = -0.13, entropy = 2.56 | time = 9.15
# Epoch 145 / 1000| cum. return = 0.90 | loss: val = 0.10, pol = -0.10, entropy = 2.40 | time = 9.29
# Epoch 146 / 1000| cum. return = 0.92 | loss: val = 0.10, pol = -0.18, entropy = 2.26 | time = 8.74
# Epoch 147 / 1000| cum. return = 0.92 | loss: val = 0.08, pol = -0.07, entropy = 2.19 | time = 8.69
# Epoch 148 / 1000| cum. return = 0.92 | loss: val = 0.07, pol = -0.08, entropy = 2.38 | time = 8.69
# Epoch 149 / 1000| cum. return = 0.92 | loss: val = 0.08, pol = -0.11, entropy = 2.31 | time = 8.50
# Epoch 150 / 1000| cum. return = 0.93 | loss: val = 0.07, pol = -0.13, entropy = 2.09 | time = 8.47
# Epoch 151 / 1000| cum. return = 0.93 | loss: val = 0.06, pol = -0.07, entropy = 2.25 | time = 8.25
# Epoch 152 / 1000| cum. return = 0.93 | loss: val = 0.10, pol = -0.18, entropy = 2.20 | time = 8.30
# Epoch 153 / 1000| cum. return = 0.93 | loss: val = 0.06, pol = -0.09, entropy = 2.09 | time = 8.72
# Epoch 154 / 1000| cum. return = 0.94 | loss: val = 0.09, pol = -0.16, entropy = 2.08 | time = 8.16
# Epoch 155 / 1000| cum. return = 0.94 | loss: val = 0.07, pol = -0.07, entropy = 2.25 | time = 8.40
# Epoch 156 / 1000| cum. return = 0.93 | loss: val = 0.06, pol = -0.15, entropy = 2.24 | time = 8.11
# Epoch 157 / 1000| cum. return = 0.93 | loss: val = 0.06, pol = -0.10, entropy = 2.23 | time = 8.49
# Epoch 158 / 1000| cum. return = 0.95 | loss: val = 0.06, pol = -0.15, entropy = 1.95 | time = 8.05
# Epoch 159 / 1000| cum. return = 0.94 | loss: val = 0.06, pol = -0.07, entropy = 2.02 | time = 8.50
# Epoch 160 / 1000| cum. return = 0.94 | loss: val = 0.05, pol = -0.08, entropy = 2.13 | time = 8.24
# Epoch 161 / 1000| cum. return = 0.94 | loss: val = 0.05, pol = -0.07, entropy = 2.21 | time = 8.98
# Epoch 162 / 1000| cum. return = 0.94 | loss: val = 0.06, pol = -0.10, entropy = 2.14 | time = 8.77
# Epoch 163 / 1000| cum. return = 0.94 | loss: val = 0.05, pol = -0.07, entropy = 2.08 | time = 8.85
# Epoch 164 / 1000| cum. return = 0.94 | loss: val = 0.05, pol = -0.07, entropy = 2.08 | time = 8.67
# Epoch 165 / 1000| cum. return = 0.95 | loss: val = 0.06, pol = -0.09, entropy = 2.23 | time = 9.15
# Epoch 166 / 1000| cum. return = 0.94 | loss: val = 0.06, pol = -0.09, entropy = 2.20 | time = 9.30
# Epoch 167 / 1000| cum. return = 0.86 | loss: val = 0.23, pol = -0.26, entropy = 2.25 | time = 8.95
# Epoch 168 / 1000| cum. return = 0.81 | loss: val = 0.32, pol = -0.07, entropy = 2.18 | time = 9.12
# Epoch 169 / 1000| cum. return = 0.94 | loss: val = 0.10, pol = -0.11, entropy = 2.13 | time = 9.15
# Epoch 170 / 1000| cum. return = 0.93 | loss: val = 0.06, pol = -0.14, entropy = 2.04 | time = 8.98
# Epoch 171 / 1000| cum. return = 0.94 | loss: val = 0.05, pol = -0.10, entropy = 2.06 | time = 9.35
# Epoch 172 / 1000| cum. return = 0.95 | loss: val = 0.05, pol = -0.08, entropy = 2.27 | time = 8.92
# Epoch 173 / 1000| cum. return = 0.94 | loss: val = 0.06, pol = -0.06, entropy = 2.14 | time = 9.10
# Epoch 174 / 1000| cum. return = 0.94 | loss: val = 0.07, pol = -0.12, entropy = 2.09 | time = 8.84
# Epoch 175 / 1000| cum. return = 0.95 | loss: val = 0.06, pol = -0.14, entropy = 2.06 | time = 8.94
# Epoch 176 / 1000| cum. return = 0.96 | loss: val = 0.05, pol = -0.09, entropy = 1.94 | time = 8.60
# Epoch 177 / 1000| cum. return = 0.95 | loss: val = 0.06, pol = -0.10, entropy = 1.91 | time = 8.67
# Epoch 178 / 1000| cum. return = 0.95 | loss: val = 0.05, pol = -0.11, entropy = 2.04 | time = 8.54
# Epoch 179 / 1000| cum. return = 0.95 | loss: val = 0.05, pol = -0.11, entropy = 1.99 | time = 8.61
# Epoch 180 / 1000| cum. return = 0.94 | loss: val = 0.05, pol = -0.10, entropy = 1.99 | time = 8.67
# Epoch 181 / 1000| cum. return = 0.95 | loss: val = 0.05, pol = -0.10, entropy = 2.12 | time = 8.66
# Epoch 182 / 1000| cum. return = 0.96 | loss: val = 0.04, pol = -0.04, entropy = 2.08 | time = 8.56
# Epoch 183 / 1000| cum. return = 0.95 | loss: val = 0.05, pol = -0.11, entropy = 2.11 | time = 8.11
# Epoch 184 / 1000| cum. return = 0.95 | loss: val = 0.05, pol = -0.07, entropy = 1.99 | time = 8.88
# Epoch 185 / 1000| cum. return = 0.95 | loss: val = 0.04, pol = -0.07, entropy = 2.11 | time = 8.74
# Epoch 186 / 1000| cum. return = 0.94 | loss: val = 0.06, pol = -0.11, entropy = 2.09 | time = 8.67
# Epoch 187 / 1000| cum. return = 0.95 | loss: val = 0.05, pol = -0.07, entropy = 1.98 | time = 8.94
# Epoch 188 / 1000| cum. return = 0.94 | loss: val = 0.06, pol = -0.09, entropy = 2.06 | time = 8.90
# Epoch 189 / 1000| cum. return = 0.94 | loss: val = 0.07, pol = -0.06, entropy = 2.19 | time = 8.60
# Epoch 190 / 1000| cum. return = 0.94 | loss: val = 0.06, pol = -0.15, entropy = 2.14 | time = 8.97
# Epoch 191 / 1000| cum. return = 0.95 | loss: val = 0.05, pol = -0.10, entropy = 2.11 | time = 8.88
# Epoch 192 / 1000| cum. return = 0.94 | loss: val = 0.05, pol = -0.10, entropy = 2.17 | time = 8.63
# Epoch 193 / 1000| cum. return = 0.95 | loss: val = 0.06, pol = -0.11, entropy = 2.06 | time = 8.38
# Epoch 194 / 1000| cum. return = 0.94 | loss: val = 0.06, pol = -0.11, entropy = 1.99 | time = 9.10
# Epoch 195 / 1000| cum. return = 0.95 | loss: val = 0.05, pol = -0.07, entropy = 1.89 | time = 9.23
# Epoch 196 / 1000| cum. return = 0.95 | loss: val = 0.04, pol = -0.07, entropy = 1.88 | time = 8.46
# Epoch 197 / 1000| cum. return = 0.95 | loss: val = 0.04, pol = -0.06, entropy = 2.09 | time = 8.65
# Epoch 198 / 1000| cum. return = 0.94 | loss: val = 0.04, pol = -0.07, entropy = 2.05 | time = 8.13
# Epoch 199 / 1000| cum. return = 0.94 | loss: val = 0.05, pol = -0.09, entropy = 2.08 | time = 8.26
# Epoch 200 / 1000| cum. return = 0.95 | loss: val = 0.04, pol = -0.07, entropy = 2.01 | time = 8.43
# Epoch 201 / 1000| cum. return = 0.95 | loss: val = 0.04, pol = -0.06, entropy = 1.92 | time = 8.71
# Epoch 202 / 1000| cum. return = 0.95 | loss: val = 0.05, pol = -0.08, entropy = 2.00 | time = 9.02
# Epoch 203 / 1000| cum. return = 0.95 | loss: val = 0.05, pol = -0.07, entropy = 2.12 | time = 8.93
# Epoch 204 / 1000| cum. return = 0.95 | loss: val = 0.05, pol = -0.09, entropy = 2.07 | time = 8.65
# Epoch 205 / 1000| cum. return = 0.94 | loss: val = 0.07, pol = -0.09, entropy = 2.08 | time = 9.06
# Epoch 206 / 1000| cum. return = 0.94 | loss: val = 0.05, pol = -0.09, entropy = 1.96 | time = 8.75
# Epoch 207 / 1000| cum. return = 0.94 | loss: val = 0.05, pol = -0.08, entropy = 1.93 | time = 8.90
# Epoch 208 / 1000| cum. return = 0.95 | loss: val = 0.04, pol = -0.05, entropy = 1.85 | time = 8.73
# Epoch 209 / 1000| cum. return = 0.95 | loss: val = 0.04, pol = -0.07, entropy = 1.93 | time = 8.42
# Epoch 210 / 1000| cum. return = 0.95 | loss: val = 0.04, pol = -0.07, entropy = 2.02 | time = 8.53
# Epoch 211 / 1000| cum. return = 0.94 | loss: val = 0.04, pol = -0.07, entropy = 2.10 | time = 9.15
# Epoch 212 / 1000| cum. return = 0.94 | loss: val = 0.04, pol = -0.09, entropy = 2.13 | time = 8.72
# Epoch 213 / 1000| cum. return = 0.94 | loss: val = 0.05, pol = -0.12, entropy = 1.95 | time = 8.55
# Epoch 214 / 1000| cum. return = 0.95 | loss: val = 0.04, pol = -0.05, entropy = 2.00 | time = 8.27
# Epoch 215 / 1000| cum. return = 0.94 | loss: val = 0.04, pol = -0.07, entropy = 2.05 | time = 8.17
# Epoch 216 / 1000| cum. return = 0.93 | loss: val = 0.08, pol = -0.08, entropy = 2.09 | time = 8.61
# Epoch 217 / 1000| cum. return = 0.93 | loss: val = 0.08, pol = -0.07, entropy = 2.24 | time = 8.50
# Epoch 218 / 1000| cum. return = 0.94 | loss: val = 0.06, pol = -0.10, entropy = 2.13 | time = 8.18
# Epoch 219 / 1000| cum. return = 0.95 | loss: val = 0.05, pol = -0.03, entropy = 2.10 | time = 8.43
# Epoch 220 / 1000| cum. return = 0.96 | loss: val = 0.05, pol = -0.06, entropy = 1.98 | time = 8.24
# Epoch 221 / 1000| cum. return = 0.95 | loss: val = 0.03, pol = -0.05, entropy = 2.07 | time = 8.52
# Epoch 222 / 1000| cum. return = 0.95 | loss: val = 0.04, pol = -0.05, entropy = 2.06 | time = 8.54
# Epoch 223 / 1000| cum. return = 0.95 | loss: val = 0.04, pol = -0.07, entropy = 2.07 | time = 7.99
# Epoch 224 / 1000| cum. return = 0.94 | loss: val = 0.04, pol = -0.08, entropy = 2.00 | time = 8.27
# Epoch 225 / 1000| cum. return = 0.95 | loss: val = 0.04, pol = -0.05, entropy = 1.95 | time = 8.33
# Epoch 226 / 1000| cum. return = 0.95 | loss: val = 0.05, pol = -0.08, entropy = 1.94 | time = 8.47
# Epoch 227 / 1000| cum. return = 0.95 | loss: val = 0.04, pol = -0.07, entropy = 1.83 | time = 8.58
# Epoch 228 / 1000| cum. return = 0.95 | loss: val = 0.04, pol = -0.03, entropy = 1.91 | time = 9.02
# Epoch 229 / 1000| cum. return = 0.95 | loss: val = 0.04, pol = -0.03, entropy = 1.92 | time = 8.47
# Epoch 230 / 1000| cum. return = 0.95 | loss: val = 0.04, pol = -0.06, entropy = 1.99 | time = 9.53
# Epoch 231 / 1000| cum. return = 0.95 | loss: val = 0.04, pol = -0.06, entropy = 2.01 | time = 8.76
# Epoch 232 / 1000| cum. return = 0.95 | loss: val = 0.03, pol = -0.04, entropy = 2.04 | time = 8.94
# Epoch 233 / 1000| cum. return = 0.94 | loss: val = 0.05, pol = -0.07, entropy = 2.09 | time = 8.77
# Epoch 234 / 1000| cum. return = 0.94 | loss: val = 0.05, pol = -0.10, entropy = 2.13 | time = 8.85
# Epoch 235 / 1000| cum. return = 0.94 | loss: val = 0.05, pol = -0.08, entropy = 2.00 | time = 8.79
# Epoch 236 / 1000| cum. return = 0.95 | loss: val = 0.04, pol = -0.05, entropy = 1.98 | time = 9.16
# Epoch 237 / 1000| cum. return = 0.95 | loss: val = 0.04, pol = -0.02, entropy = 2.04 | time = 8.99
# Epoch 238 / 1000| cum. return = 0.95 | loss: val = 0.03, pol = -0.04, entropy = 2.11 | time = 8.47
# Epoch 239 / 1000| cum. return = 0.95 | loss: val = 0.06, pol = -0.08, entropy = 2.11 | time = 8.47
# Epoch 240 / 1000| cum. return = 0.95 | loss: val = 0.05, pol = -0.06, entropy = 2.01 | time = 8.86
# Epoch 241 / 1000| cum. return = 0.95 | loss: val = 0.04, pol = -0.06, entropy = 2.13 | time = 8.49
# Epoch 242 / 1000| cum. return = 0.95 | loss: val = 0.04, pol = -0.04, entropy = 2.13 | time = 9.18
# Epoch 243 / 1000| cum. return = 0.94 | loss: val = 0.03, pol = -0.06, entropy = 2.11 | time = 8.34
# Epoch 244 / 1000| cum. return = 0.94 | loss: val = 0.05, pol = -0.11, entropy = 2.18 | time = 8.25
# Epoch 245 / 1000| cum. return = 0.94 | loss: val = 0.05, pol = -0.05, entropy = 2.04 | time = 8.75
# Epoch 246 / 1000| cum. return = 0.91 | loss: val = 0.08, pol = -0.01, entropy = 2.04 | time = 8.65
# Epoch 247 / 1000| cum. return = 0.90 | loss: val = 0.08, pol = -0.08, entropy = 2.41 | time = 8.43
# Epoch 248 / 1000| cum. return = 0.92 | loss: val = 0.07, pol = -0.10, entropy = 2.52 | time = 9.08
# Epoch 249 / 1000| cum. return = 0.94 | loss: val = 0.05, pol = -0.11, entropy = 2.16 | time = 9.66
# Epoch 250 / 1000| cum. return = 0.95 | loss: val = 0.04, pol = -0.08, entropy = 2.14 | time = 8.69
# Epoch 251 / 1000| cum. return = 0.94 | loss: val = 0.05, pol = -0.07, entropy = 2.09 | time = 8.55
# Epoch 252 / 1000| cum. return = 0.95 | loss: val = 0.04, pol = -0.05, entropy = 2.10 | time = 8.56
# Epoch 253 / 1000| cum. return = 0.95 | loss: val = 0.04, pol = -0.08, entropy = 2.08 | time = 8.46
# Epoch 254 / 1000| cum. return = 0.95 | loss: val = 0.04, pol = -0.04, entropy = 2.04 | time = 8.43
# Epoch 255 / 1000| cum. return = 0.94 | loss: val = 0.04, pol = -0.06, entropy = 2.03 | time = 8.63
# Epoch 256 / 1000| cum. return = 0.94 | loss: val = 0.05, pol = -0.09, entropy = 2.03 | time = 8.65
# Epoch 257 / 1000| cum. return = 0.95 | loss: val = 0.04, pol = -0.09, entropy = 2.03 | time = 9.08
# Epoch 258 / 1000| cum. return = 0.94 | loss: val = 0.04, pol = -0.08, entropy = 2.07 | time = 8.95
# Epoch 259 / 1000| cum. return = 0.95 | loss: val = 0.04, pol = -0.10, entropy = 2.05 | time = 9.38
# Epoch 260 / 1000| cum. return = 0.95 | loss: val = 0.03, pol = -0.04, entropy = 2.06 | time = 8.24
# Epoch 261 / 1000| cum. return = 0.94 | loss: val = 0.04, pol = -0.05, entropy = 2.10 | time = 8.70
# Epoch 262 / 1000| cum. return = 0.95 | loss: val = 0.03, pol = -0.09, entropy = 2.11 | time = 8.64
# Epoch 263 / 1000| cum. return = 0.95 | loss: val = 0.04, pol = -0.03, entropy = 2.06 | time = 9.00
# Epoch 264 / 1000| cum. return = 0.94 | loss: val = 0.03, pol = -0.05, entropy = 2.13 | time = 8.82
# Epoch 265 / 1000| cum. return = 0.94 | loss: val = 0.04, pol = -0.06, entropy = 2.12 | time = 8.65
# Epoch 266 / 1000| cum. return = 0.94 | loss: val = 0.04, pol = -0.08, entropy = 2.10 | time = 8.40
# Epoch 267 / 1000| cum. return = 0.94 | loss: val = 0.03, pol = -0.07, entropy = 2.12 | time = 8.20
# Epoch 268 / 1000| cum. return = 0.95 | loss: val = 0.04, pol = -0.06, entropy = 2.12 | time = 8.67
# Epoch 269 / 1000| cum. return = 0.95 | loss: val = 0.04, pol = -0.07, entropy = 2.14 | time = 9.32
# Epoch 270 / 1000| cum. return = 0.94 | loss: val = 0.06, pol = -0.09, entropy = 2.15 | time = 8.76
# Epoch 271 / 1000| cum. return = 0.94 | loss: val = 0.05, pol = -0.07, entropy = 2.13 | time = 8.32
# Epoch 272 / 1000| cum. return = 0.95 | loss: val = 0.03, pol = -0.06, entropy = 2.05 | time = 8.61
# Epoch 273 / 1000| cum. return = 0.95 | loss: val = 0.04, pol = -0.04, entropy = 2.08 | time = 8.36
# Epoch 274 / 1000| cum. return = 0.95 | loss: val = 0.04, pol = -0.08, entropy = 2.11 | time = 8.04
# Epoch 275 / 1000| cum. return = 0.94 | loss: val = 0.07, pol = -0.02, entropy = 2.07 | time = 8.69
# Epoch 276 / 1000| cum. return = 0.94 | loss: val = 0.05, pol = -0.11, entropy = 2.10 | time = 8.37
# Epoch 277 / 1000| cum. return = 0.93 | loss: val = 0.05, pol = -0.08, entropy = 2.09 | time = 8.39
# Epoch 278 / 1000| cum. return = 0.94 | loss: val = 0.04, pol = -0.09, entropy = 2.06 | time = 8.31
# Epoch 279 / 1000| cum. return = 0.95 | loss: val = 0.04, pol = -0.07, entropy = 2.03 | time = 8.55
# Epoch 280 / 1000| cum. return = 0.94 | loss: val = 0.04, pol = -0.05, entropy = 2.17 | time = 8.44
# Epoch 281 / 1000| cum. return = 0.95 | loss: val = 0.04, pol = -0.08, entropy = 2.10 | time = 8.43
# Epoch 282 / 1000| cum. return = 0.94 | loss: val = 0.04, pol = -0.07, entropy = 2.09 | time = 8.54
# Epoch 283 / 1000| cum. return = 0.95 | loss: val = 0.04, pol = -0.04, entropy = 1.97 | time = 8.13
# Epoch 284 / 1000| cum. return = 0.95 | loss: val = 0.04, pol = -0.07, entropy = 1.97 | time = 8.14
# Epoch 285 / 1000| cum. return = 0.95 | loss: val = 0.04, pol = -0.05, entropy = 2.00 | time = 8.53
# Epoch 286 / 1000| cum. return = 0.94 | loss: val = 0.04, pol = -0.06, entropy = 2.05 | time = 8.84
# Epoch 287 / 1000| cum. return = 0.95 | loss: val = 0.04, pol = -0.07, entropy = 2.12 | time = 8.11
# Epoch 288 / 1000| cum. return = 0.95 | loss: val = 0.04, pol = -0.05, entropy = 2.05 | time = 8.42
# Epoch 289 / 1000| cum. return = 0.95 | loss: val = 0.04, pol = -0.05, entropy = 2.02 | time = 7.96
# Epoch 290 / 1000| cum. return = 0.95 | loss: val = 0.03, pol = -0.05, entropy = 2.02 | time = 8.24
# Epoch 291 / 1000| cum. return = 0.95 | loss: val = 0.03, pol = -0.06, entropy = 2.01 | time = 8.36
# Epoch 292 / 1000| cum. return = 0.94 | loss: val = 0.03, pol = -0.07, entropy = 2.02 | time = 8.21
# Epoch 293 / 1000| cum. return = 0.95 | loss: val = 0.03, pol = -0.04, entropy = 2.04 | time = 8.17
# Epoch 294 / 1000| cum. return = 0.95 | loss: val = 0.04, pol = -0.09, entropy = 2.10 | time = 8.44
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-9472617593b3> in <module>
#       1 '''train model'''
#       2
# ----> 3 out, avg_train_loss, avg_cum_rewards, _ = trainer.train()
#       4 n_epochs = trainer.current_epoch + 1
#
# /notebooks/compositional_metarl/trainers/trainers.py in train(self)
#     896             bag_of_tasks = self.make_bag_of_tasks(self.dataloaders.cues, self.dataloaders.num_blocks, self.n_rounds, block_structure=self.block_structure)
#     897
# --> 898             loss = self.train_one_epoch(bag_of_tasks)
#     899             self.train_losses.append(loss)
#     900             self.mean_cum_reward = self.log_cum_return[self.current_epoch].mean()
#
# /notebooks/compositional_metarl/trainers/trainers.py in train_one_epoch(self, bag_of_tasks)
#     854             X, Y, S = self.dataloaders.sample(end_rnd=1, block=block)
#     855             # run nmodel and update parameters
# --> 856             losses_ = self.train_one_block(X, Y, S, block, block_indx)
#     857
#     858
#
# /notebooks/compositional_metarl/trainers/trainers.py in train_one_block(self, X, Y, S, block, block_indx)
#     796
#     797         # train one episode
# --> 798         rewards, probs, values, entropys, cumulative_reward = self.train_one_episode(X, Y, S, cues, num_trials)
#     799         loss, cache = self.compute_loss(rewards, probs, values, entropys)
#     800
#
# /notebooks/compositional_metarl/trainers/trainers.py in train_one_episode(self, X, Y, S, cues, n_trials)
#     751
#     752             x_t =  self._input(X[trial], S[trial], a_t, r_t, trial%self.n_trials)
# --> 753             output_t, cache_t = self.model(x_t, h_t, c_t)
#     754             a_t, prob_a_t, v_t, h_t, c_t = output_t
#     755             f_t, i_t, o_t, rg_t, m_t, q_t, p_at = cache_t
#
# /usr/local/lib/python3.8/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     725             result = self._slow_forward(*input, **kwargs)
#     726         else:
# --> 727             result = self.forward(*input, **kwargs)
#     728         for hook in itertools.chain(
#     729                 _global_forward_hooks.values(),
#
# /notebooks/compositional_metarl/model/QDNDLSTM.py in forward(self, x_t, h, c)
#      75         c_t = torch.mul(f_t, c) + torch.mul(i_t, c_t_new)
#      76         # retrieve memory
# ---> 77         m_t = self.dnd.get_memory(x_t[:self.ctx_dim], self.dnd_policy).tanh()
#      78         # gate the memory; in general, can be any transformation of it
#      79         c_t = c_t + torch.mul(r_t, m_t)
#
# /notebooks/compositional_metarl/model/DND.py in get_memory(self, query_key, policy)
#     128         similarities = compute_similarities(query_key, self.keys, self.kernel)
#     129         # get the best-match memory
# --> 130         best_memory_val = self._get_memory(similarities, policy)
#     131         return best_memory_val
#     132
#
# /notebooks/compositional_metarl/model/DND.py in _get_memory(self, similarities, policy)
#     160         elif policy == 'softmax':
#     161             weights = softmax(similarities, beta=1)
# --> 162             best_memory_val = compute_weighted_sum(weights.reshape(-1), self.vals)
#     163         else:
#     164             raise ValueError(f'unrecog recall policy: {policy}')
#
# /notebooks/compositional_metarl/model/DND.py in compute_weighted_sum(weights, values)
#     239             retreive_memory_val = weights[idx]*values[idx]
#     240         else:
# --> 241             retreive_memory_val += weights[idx]*values[idx]
#     242     return retreive_memory_val
#
# KeyboardInterrupt:

# %% [raw]
# n_epochs = 500 #trainer.current_epoch

# %% [markdown]
# ## save model

# %% [raw]
# train_protocol = 'blockMAB'
# filename = f"agent_{train_protocol}_{inputs}_hiddim{dim_hidden}_kernel{kernel}_policy{dnd_policy}"

# %% [raw]
# torch.save(agent.state_dict(), filename+".pt")

# %% [raw]
# np.savez(filename+".npz", n_arms=n_arms, ctx_dim=ctx_dim, n_blocks=trainer.n_blocks, n_epochs=trainer.current_epoch, n_trials=trainer.n_trials, log_cum_return=trainer.log_cum_return,
#          log_return=trainer.log_return, log_regret=trainer.log_regret, log_loss_value=trainer.log_loss_value, log_loss_policy=trainer.log_loss_policy,
#          log_loss_entropy=trainer.log_loss_entropy)

# %% [markdown]
# ## figures

# %%
'''loss functions'''

f, axes = plt.subplots(1, 2, figsize=(10, 5), dpi=125)
axes[0].plot(trainer.log_loss_policy.mean(1)[:n_epochs])
axes[0].xaxis.set_major_locator(MaxNLocator(integer=True))
axes[0].set_ylabel('Policy loss')
axes[0].set_xlabel('Epoch')

axes[1].plot(trainer.log_loss_value.mean(1)[:n_epochs])
axes[1].xaxis.set_major_locator(MaxNLocator(integer=True))
axes[1].set_ylabel('Value loss')
axes[1].set_xlabel('Epoch')

plt.legend(CUES)
sns.despine()
f.tight_layout()

# %%
'''learning curves'''

f, axes = plt.subplots(1, 2, figsize=(10, 5), dpi=125)
axes[0].plot(trainer.log_cum_return.mean(2)[:n_epochs])
axes[0].set_ylabel('Return')
axes[0].set_xlabel('Epoch')
axes[0].xaxis.set_major_locator(MaxNLocator(integer=True))
# axes[0].plot(np.repeat(log_Y[:, 0, :, 7].mean(1).mean(), n_epochs), '_k')

# axes[1].plot(log_regret.mean(3).mean(2)) # mean regreat across trials and rounds
axes[1].plot(trainer.log_regret.cumsum(3).max(3).mean(2)[:n_epochs])
axes[1].xaxis.set_major_locator(MaxNLocator(integer=True))
axes[1].set_ylabel('Cum. Regret')
axes[1].set_xlabel('Epoch')

axes[0].legend(CUES)
sns.despine()
f.tight_layout()

# %% [raw]
# trainer.shuffle_cues()

# %%
''' model evaluation for different cues'''

block = ['linneg', 'pereven', 'linperiodic'] 
if composition_block is False:
    trainer.dataloaders.evaluate_control()
X, Y, S = trainer.dataloaders.sample(end_rnd=1, block=block)
n_runs = 1

# create block structure
X, Y, S, _ = trainer.dataloaders.prepare_data(X, Y, S, block, n_trials)
total_trials =  n_trials if trainer.dataloaders.eval_control else len(block) * n_trials
init_at = None

# %%
n_runs = 100

# %% [raw]
# YY[20:] = Y[20:]

# %%
Y[20:] = YY[20:]

# %%
f, ax = plt.subplots(1, 1, figsize=(7, 5), dpi=100)
ax.plot(Y[29].T, 'red', lw=2, label='Structure @Eval')
ax.plot((Y[0]+Y[10]).T/2, 'k', lw=2, label='True Structure')
ax.legend(loc='upper right')
plt.show()

# %%
f.savefig('/notebooks/figs/'+'wrongstructureateval'+'_'.join(block[:2]))

# %%
actions, rewards, values, regrets =  np.zeros((n_runs, total_trials)),  np.zeros((n_runs, total_trials)), np.zeros((n_runs, total_trials, n_arms)),  np.zeros((n_runs, total_trials))

for run_id in range(n_runs):
    actions[run_id], rewards[run_id], regrets[run_id], values[run_id] = run_model_eval(agent, X, Y, S)

# %%
# avg reward across trials
f, ax = plt.subplots(1, 2, figsize=(12, 4), dpi=100)
ax[0].errorbar(range(1, n_trials+1), rewards[:,20:].mean(0), yerr=rewards[:,20:].std(0))
ax[0].set_title('Avg. Return per trial')
ax[0].set_xlabel('Trials')
ax[0].xaxis.set_major_locator(MaxNLocator(integer=True))

# # avg regret across trials
# ax[1].errorbar(range(1, n_trials+1), regrets[:,20:].mean(0), yerr=regrets[:,20:].std(0))
# ax[1].set_title('Avg. Regret per-trial')
# ax[1].set_xlabel('Trials')
# ax[1].xaxis.set_major_locator(MaxNLocator(integer=True))
 
# avg qvalues
ax[1].plot(Y[29].T, 'red', lw=2, label='Structure @Eval')
ax[1].errorbar(range(n_arms), values[:,20:].mean(0).mean(0), yerr=values[:,20:].mean(0).std(0), label='Predicted Q-values')
ax[1].set_title('Q-values')
ax[1].set_xlabel('Arms')
ax[1].legend(loc='lower right')
ax[1].xaxis.set_major_locator(MaxNLocator(integer=True))

plt.show()

# %%
f.savefig('/notebooks/figs/'+'wrongstructureateval_reward'+'_'.join(block[:2]))

# %% [raw]
# # avg reward across trials
# f, ax = plt.subplots(1, 2, figsize=(14, 4), dpi=100)
# ax[0].errorbar(range(1, total_trials+1), rewards.mean(0), yerr=rewards.std(0))
# ax[0].set_title('Avg. Return per trial')
# ax[0].set_xlabel('Trials')
# ax[0].xaxis.set_major_locator(MaxNLocator(integer=True))
#
# # avg regret across trials
# ax[1].errorbar(range(1, total_trials+1), regrets.mean(0), yerr=regrets.std(0))
# ax[1].set_title('Avg. Regret per-trial')
# ax[1].set_xlabel('Trials')
# ax[1].xaxis.set_major_locator(MaxNLocator(integer=True))
#
# plt.show()

# %% [raw]
# def run_model_eval(agent, X, Y, S, init_at=None):
#
#     aa, vv, rr, rs =  [], [], [], []
#
#     # run model for n_runs
#     agent.eval()
#     agent.turn_off_encoding()
#
#     # set init states
#     h_t, c_t = agent.get_init_states()
#     h_t, c_t = torch.zeros_like(h_t), torch.zeros_like(c_t)
#     a_t = init_at
#     r_t = Y[0].mean()
#
#
#     # run model
#     for t in range(total_trials):
#         x_t = X[t]
#         s_t = S[t]
#         trial = t%n_trials
#         #print(x_t, s_t, r_t)
#         if agent.inputs == 'context_block_action_reward':
#             one_hot_a_t = one_hot_embedding(a_t, n_arms)
#             #print(x_t, s_t, one_hot_a_t, trial, r_t)
#             x_t = torch.cat((x_t.type(torch.FloatTensor), s_t.reshape(-1).type(torch.FloatTensor), one_hot_a_t.reshape(-1).type(torch.FloatTensor),
#                              r_t.reshape(-1).type(torch.FloatTensor), torch.tensor(trial).reshape(-1).type(torch.FloatTensor)), dim=0)
#         output_t, c = agent(x_t, h_t, c_t)
#         a_t, prob_a_t, v_t, h_t, c_t = output_t
#         f_t, i_t, o_t, rg_t, m_t, q_t, pa_t = c
#
#         # bootstrap reward from q-values
#         r_t = Y[t][a_t]
#
#
#         # predicted q-value
#         Q = q_t.detach().numpy().T
#         Q = Q - Q.min()
#         Q = Q/Q.max()
#
#         # store results
#         rs.append(r_t)
#         aa.append(a_t)
#         rr.append(Y[t].max() - r_t)
#         vv.append(Q)
#
#     return torch.stack(aa), torch.stack(rs), torch.stack(rr), np.hstack(vv).T

# %% [raw]
# def one_hot_embedding(arm, num_arms):
#     """Embedding labels to one-hot form.
#
#     Args:
#       arms: (LongTensor) arms for which embedding is required, sized [N,].
#       num_arms: (int) number of arms.
#
#     Returns:
#       (tensor) encoded arms, sized [N, #classes].
#     """
#     y = torch.eye(num_arms)
#
#     return torch.zeros(num_arms) if arm is None else y[arm]

# %%
''' model evaluation for different cues'''

block = ['linneg', 'pereven', 'linperiodic'] 
X, Y, S = trainer.dataloaders.sample(end_rnd=1, block=block)
ind = 2
n_runs = 10

# %%
#### n_cues = len(CUES)
 
# set up the color scheme
f, ax = plt.subplots(1, 4, figsize=(30, 5), dpi=100)
c = np.arange(n_runs+1)
norm = mpl.colors.Normalize(vmin=c.min(), vmax=c.max())
cmap = mpl.cm.ScalarMappable(norm=norm, cmap=mpl.cm.cividis_r)
cmap.set_array([])

# run model for n_runs
agent.eval()
agent.turn_off_encoding()

# set init states
h_t, c_t = agent.get_init_states()
#h_t, c_t = torch.zeros_like(h_t), torch.zeros_like(c_t)  
a_t = 4 # torch.randint(high=dim_output,size=(1,)) 
r_t = Y[ind-1][a_t] 
print(r_t, a_t)
 
ax[0].plot(Y[ind].T, c='k', lw=4)
ax[0].set(xlabel='Arms', title = block[ind])
actions, dist, values, temps = [], [], [], []

# run model
for t in range(n_runs):
    h_t1 = h_t
    c_t1 = c_t
    x_t = X[ind] 
    s_t = S[ind] #torch.tensor([1])
    print(x_t, s_t)
    if inputs == 'context_block_action_reward':
        one_hot_a_t = one_hot_embedding(a_t, n_arms)
        x_t = torch.cat((x_t.type(torch.FloatTensor), s_t.reshape(-1).type(torch.FloatTensor), one_hot_a_t.reshape(-1).type(torch.FloatTensor), 
                         r_t.reshape(-1).type(torch.FloatTensor), torch.tensor(t%n_trials).reshape(-1).type(torch.FloatTensor)), dim=0)
    output_t, c = agent(x_t, h_t, c_t)
    a_t, prob_a_t, v_t, h_t, c_t = output_t
    f_t, i_t, o_t, rg_t, m_t, q_t, pa_t = c
    a_t = torch.argmax(q_t)
    
    # bootstrap reward from q-values
    r_t = Y[ind][a_t]  
    print(r_t, a_t)
    if t>=0:
        Q = q_t.detach().numpy().T
        Q = Q - Q.min()
        Q = Q/Q.max()
        ax[1].plot(Q, c=cmap.to_rgba(t + 1))
    
    
    dist.append(torch.sum(F.pairwise_distance(h_t1, h_t, p=2)))
    actions.append(a_t) 
    temps.append(1. - r_t) 
    # values.append(q_t[0][aoi[cue]]) 
    
# format figure
ax[1].xaxis.set_major_locator(MaxNLocator(integer=True))
ax[1].set(xlabel='Arms',
       ylabel='Q-value',
      title= 'Q-values for {}'.format(block[ind]))
cbar = plt.colorbar(cmap, ticks=np.arange(n_runs+1, step=n_runs/5), ax=ax[0])
cbar.set_label('Runs', rotation=90)

_ = ax[2].hist(actions[:t])
ax[2].set(xlabel='Arm',
       ylabel='Number of runs per arm')
ax[3].plot(np.cumsum(torch.stack(temps).cpu().data.numpy())[:t])
ax[3].set(xlabel='Runs',
       ylabel='Regret',
      title='Cumulative regrets across runs')


sns.despine()
plt.show()
# Out:
# tensor(1.) 4
# tensor([1., 1.]) tensor([2])
# tensor(0.8571) tensor(2)
# tensor([1., 1.]) tensor([2])
# tensor(1.) tensor(0)
# tensor([1., 1.]) tensor([2])
# tensor(1.) tensor(0)
# tensor([1., 1.]) tensor([2])
# tensor(1.) tensor(0)
# tensor([1., 1.]) tensor([2])
# tensor(0.5714) tensor(6)
# tensor([1., 1.]) tensor([2])
# tensor(0.5714) tensor(6)
# tensor([1., 1.]) tensor([2])
# tensor(0.5714) tensor(6)
# tensor([1., 1.]) tensor([2])
# tensor(0.5714) tensor(6)
# tensor([1., 1.]) tensor([2])
# tensor(0.5714) tensor(6)
# tensor([1., 1.]) tensor([2])
# tensor(0.5714) tensor(6)

# %%
''' model evaluation for different cues'''

block = ['linear', 'periodic', 'linperiodic'] #, 'linperiodic']
X, Y, S = trainer.dataloaders.sample(end_rnd=1, block=block)
n_runs = 10

# create block structure
X = np.repeat(X, n_runs, axis=0)
Y = np.repeat(Y, n_runs, axis=0)
S = np.repeat(S, n_runs, axis=0)
init_at = 4 
n_vis = 30

# %%
n_cues = len(CUES)
 
# set up the color scheme
c = np.arange(n_vis+1)
norm = mpl.colors.Normalize(vmin=c.min(), vmax=c.max())
cmap = mpl.cm.ScalarMappable(norm=norm, cmap=mpl.cm.cividis_r)
cmap.set_array([])

# run model for n_runs
agent.eval()
agent.turn_off_encoding()

# set init states
h_t, c_t = agent.get_init_states()
h_t, c_t = torch.zeros_like(h_t), torch.zeros_like(c_t)

# %%
f, ax = plt.subplots(1, 4, figsize=(30, 5), dpi=100)
actions, dist, values, temps = [], [], [], []

r_t = Y[0][init_at] 
print(r_t, init_at)
# run model
for t in range(0, n_vis):
    h_t1 = h_t
    c_t1 = c_t
    x_t = X[t] 
    s_t = S[t]
    
    trial = t%n_trials
    if inputs == 'context_block_action_reward':
        one_hot_a_t = one_hot_embedding(a_t, n_arms)
        x_t = torch.cat((x_t.type(torch.FloatTensor), s_t.reshape(-1).type(torch.FloatTensor), one_hot_a_t.reshape(-1).type(torch.FloatTensor), 
                         r_t.reshape(-1).type(torch.FloatTensor), torch.tensor(trial).reshape(-1).type(torch.FloatTensor)), dim=0)
    output_t, c = agent(x_t, h_t, c_t)
    a_t, prob_a_t, v_t, h_t, c_t = output_t
    f_t, i_t, o_t, rg_t, m_t, q_t, pa_t = c
    a_t = torch.argmax(q_t)
    #if AOI['_'.join(block[:2])] == a_t:
    #    print('chooses best arm in second trial')
    
    # bootstrap reward from q-values
    r_t = Y[t][a_t] 
    print(r_t, a_t)
    
    if t>=0:
        ax[0].plot(Y[t].T, c='k', lw=4)

        Q = q_t.detach().numpy().T
        Q = Q - Q.min()
        Q = Q/Q.max()
        ax[1].plot(Q, c=cmap.to_rgba(t + 1))
        actions.append(a_t) 
        temps.append(1. - r_t)
        
    if (t+1)%n_trials==0 and t<(n_vis-1):
        print(t)
        #h_t, c_t = agent.get_init_states()
        r_t = Y[t+1][init_at]
        print(r_t, init_at)
   
    dist.append(torch.sum(F.pairwise_distance(h_t1, h_t, p=2)))
    
# format figure
ax[0].set(xlabel='Arms')
ax[1].xaxis.set_major_locator(MaxNLocator(integer=True))
ax[1].set(xlabel='Arms',
          ylabel='Q-value',
          title= 'Q-values')
cbar = plt.colorbar(cmap, ticks=np.arange(n_vis+1, step=n_vis/5), ax=ax[1])
cbar.set_label('', rotation=90)

_ = ax[2].hist(actions[:t])
ax[2].set(xlabel='Arm',
       ylabel='Number of runs per arm')
ax[3].plot(np.cumsum(torch.stack(temps).cpu().data.numpy())[:t])
ax[3].set(xlabel='Runs',
       ylabel='Regret',
      title='Cumulative regrets across runs')


sns.despine()
plt.show()
# Out:
# tensor(0.4286) 4
# tensor(1.) tensor(0)
# tensor(1.) tensor(0)
# tensor(1.) tensor(0)
# tensor(1.) tensor(0)
# tensor(1.) tensor(0)
# tensor(1.) tensor(0)
# tensor(1.) tensor(0)
# tensor(1.) tensor(0)
# tensor(1.) tensor(0)
# tensor(1.) tensor(0)
# 9
# tensor(1.7285e-07) 4
# tensor(1.) tensor(5)
# tensor(1.) tensor(1)
# tensor(1.) tensor(1)
# tensor(1.) tensor(1)
# tensor(1.) tensor(1)
# tensor(1.) tensor(3)
# tensor(1.) tensor(1)
# tensor(1.) tensor(3)
# tensor(1.) tensor(1)
# tensor(1.) tensor(3)
# 19
# tensor(0.1667) 4
# tensor(0.5000) tensor(0)
# tensor(0.8333) tensor(3)
# tensor(1.) tensor(1)
# tensor(1.) tensor(1)
# tensor(1.) tensor(1)
# tensor(1.) tensor(1)
# tensor(1.) tensor(1)
# tensor(1.) tensor(1)
# tensor(1.) tensor(1)
# tensor(0.8333) tensor(3)
